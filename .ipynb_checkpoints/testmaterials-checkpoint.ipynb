# %%
# %load_ext autoreload
# %autoreload 2
from IPython.display import display, Math, Latex
from materials import *
conc30 = ConcMaterial(f_ck=30)
print(conc30.latex())
Latex(conc30.latex())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# $f_{ck} = 30 \; \mathrm{MPa}  \\f_{cm} = 34.0 \; \mathrm{MPa}  \\E_{c} = 27536.700310858607 \; \mathrm{MPa}$
# $f_{ck} = 30 \; \mathrm{MPa}  \\f_{cm} = 34.0 \; \mathrm{MPa}  \\E_{c} = 27536.700310858607 \; \mathrm{MPa}$

# %%
Latex(conc30.latex())
# Out:
# $f_{ck} = 30 \; \mathrm{MPa}\\f_{cm} = 34.0 \; \mathrm{MPa}\\E_{c} = 27536.700310858607 \; \mathrm{MPa}$

# %% [markdown]
# $f_{ck} = 30$ MPa
# $f_{cm} = 34.0$ MPa
# $E_{c} = 27536.700310858607$ MPa

# %%
Latex(conc30.E_c_latex)
# Out:
# $E_{c}=8500 \times \root {3} \of {f_{cm} }  = 8500 \times \root {3} \of { 34.0 } = 27536.700310858607 \; \mathrm{MPa}$
